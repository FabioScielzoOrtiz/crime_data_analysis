# %% [markdown]
# # Homicides by Sex Data Analysis

# %% [markdown]
# ## Requirements

# %%
import os, sys
import polars as pl
import numpy as np

# %%
SCRIPT_PATH = os.getcwd() # os.path.dirname(os.path.abspath(__file__))
PROJECT_PATH = os.path.join(SCRIPT_PATH, '..')
INPUT_DIR = os.path.join(PROJECT_PATH, 'data', 'processed')
INPUT_FILE = os.path.join(INPUT_DIR, 'processed_unodc_intentional_homicide_rate.csv')
PLOTS_PATH = os.path.join(PROJECT_PATH, 'plots')
os.makedirs(PLOTS_PATH, exist_ok=True)

# %%
sys.path.append(PROJECT_PATH)

from config.config_01a import (
    SELECTED_COUNTRIES, 
    COLOR_MAP, 
    CATEGORY_ORDERS,
    HOVER_DATA,
    LABELS, 
    HOVER_TEMPLATES,
    PLOT_FILENAME,
    PROP_YEARS_IN_PERIOD_LIMIT,
    REF_REGION_FOR_START_YEAR
)

from src.plots_utils import time_series_plot, barplot
from src.analysis_utils import process_time_series_data, process_ranking_data

# %%
# Read data
df = pl.read_csv(INPUT_FILE)

# %%
# Processing for time series by country and region

by = 'Sex'

df_time_series, optimal_min_year, max_year = process_time_series_data(
    df = df, 
    selected_countries = SELECTED_COUNTRIES, 
    prop_years_in_period_limit = PROP_YEARS_IN_PERIOD_LIMIT, 
    ref_region_for_start_year = REF_REGION_FOR_START_YEAR,
    by = by
    )
# Out:
# ⚙️ Procesando desglose por: SEXO
# 📅 Periodo: 2000-2023
# ✅ Países válidos para región: 21 de 31
# --------------------------------------------------------------------------------

# %%
# Processing for Rankings by country and region

initial_years = [1990, 
                 optimal_min_year, # 2000
                 2014,
                 2019]

df_ranking_combined, df_ranking_dict = process_ranking_data(
    df = df_time_series['country'], 
    selected_countries = SELECTED_COUNTRIES, 
    prop_years_in_period_limit = PROP_YEARS_IN_PERIOD_LIMIT, 
    initial_years = initial_years, 
    max_year = max_year,
    by = by
)
# Out:
# 🔄 Procesando ranking (Sex) para: 1990-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 1990 - 2023
#    Segmentado por: Sex
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 17
#    Países descartados: ['France', 'Argentina', 'El Salvador', 'Chile', 'Republic of Korea', 'Singapore', 'China', 'Philippines', 'Indonesia', 'Thailand', 'Türkiye', 'Morocco', 'Egypt', 'South Africa']
#    Prop. datos (años) en el periodo, por pais: {'Germany': 1.0, 'Denmark': 1.0, 'USA': 1.0, 'Egypt': 0.26, 'Chile': 0.56, 'India': 0.71, 'Greece': 0.97, 'Sweden': 0.74, 'Mexico': 1.0, 'Indonesia': 0.03, 'Romania': 1.0, 'Republic of Korea': 0.38, 'Thailand': 0.56, 'Italy': 0.97, 'Argentina': 0.24, 'Brazil': 1.0, 'South Africa': 0.35, 'Colombia': 1.0, 'Japan': 1.0, 'Spain': 0.68, 'Norway': 1.0, 'Türkiye': 0.53, 'Portugal': 0.85, 'Philippines': 0.32, 'United Kingdom': 0.65, 'El Salvador': 0.53, 'Venezuela': 0.71, 'Singapore': 0.53, 'France': 0.26, 'Morocco': 0.44, 'China': 0.0}
# ----------------------------------------------------------------------------------------------------
# 🔄 Procesando ranking (Sex) para: 2000-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 2000 - 2023
#    Segmentado por: Sex
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 21
#    Países descartados: ['France', 'Argentina', 'Republic of Korea', 'China', 'Philippines', 'Indonesia', 'Thailand', 'Morocco', 'Egypt', 'South Africa']
#    Prop. datos (años) en el periodo, por pais: {'Argentina': 0.33, 'Indonesia': 0.04, 'Egypt': 0.38, 'Morocco': 0.62, 'Colombia': 1.0, 'Chile': 0.79, 'Sweden': 1.0, 'Singapore': 0.75, 'Spain': 0.96, 'Norway': 1.0, 'Thailand': 0.58, 'Portugal': 0.96, 'France': 0.38, 'Greece': 0.96, 'India': 0.96, 'Mexico': 1.0, 'Italy': 0.96, 'El Salvador': 0.75, 'Republic of Korea': 0.54, 'Philippines': 0.46, 'Japan': 1.0, 'Brazil': 1.0, 'Denmark': 1.0, 'Germany': 1.0, 'United Kingdom': 0.92, 'Venezuela': 0.67, 'Türkiye': 0.75, 'Romania': 1.0, 'South Africa': 0.5, 'USA': 1.0, 'China': 0.0}
# ----------------------------------------------------------------------------------------------------
# 🔄 Procesando ranking (Sex) para: 2014-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 2014 - 2023
#    Segmentado por: Sex
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 24
#    Países descartados: ['Venezuela', 'China', 'Philippines', 'Indonesia', 'Thailand', 'Egypt', 'South Africa']
#    Prop. datos (años) en el periodo, por pais: {'Denmark': 1.0, 'Colombia': 1.0, 'Mexico': 1.0, 'Brazil': 1.0, 'Greece': 1.0, 'Portugal': 0.9, 'Singapore': 1.0, 'Egypt': 0.2, 'Romania': 1.0, 'Venezuela': 0.3, 'Thailand': 0.1, 'Argentina': 0.8, 'Indonesia': 0.1, 'India': 0.9, 'Republic of Korea': 1.0, 'Sweden': 1.0, 'Italy': 1.0, 'USA': 1.0, 'South Africa': 0.6, 'France': 0.9, 'Japan': 1.0, 'Türkiye': 0.9, 'United Kingdom': 0.8, 'Philippines': 0.5, 'Morocco': 1.0, 'Spain': 1.0, 'Germany': 1.0, 'Norway': 1.0, 'Chile': 1.0, 'El Salvador': 0.9, 'China': 0.0}
# ----------------------------------------------------------------------------------------------------
# 🔄 Procesando ranking (Sex) para: 2019-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 2019 - 2023
#    Segmentado por: Sex
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 23
#    Países descartados: ['United Kingdom', 'Venezuela', 'China', 'Philippines', 'Indonesia', 'Thailand', 'Egypt', 'South Africa']
#    Prop. datos (años) en el periodo, por pais: {'Republic of Korea': 1.0, 'Türkiye': 1.0, 'Morocco': 1.0, 'Mexico': 1.0, 'France': 1.0, 'Norway': 1.0, 'Argentina': 1.0, 'USA': 1.0, 'Colombia': 1.0, 'United Kingdom': 0.6, 'Italy': 1.0, 'Greece': 1.0, 'India': 0.8, 'Brazil': 1.0, 'South Africa': 0.6, 'Spain': 1.0, 'Sweden': 1.0, 'Denmark': 1.0, 'Philippines': 0.4, 'Indonesia': 0.2, 'Singapore': 1.0, 'Portugal': 0.8, 'Germany': 1.0, 'Egypt': 0.4, 'El Salvador': 0.8, 'Chile': 1.0, 'Japan': 1.0, 'Romania': 1.0, 'Venezuela': 0.0, 'China': 0.0, 'Thailand': 0.0}
# ----------------------------------------------------------------------------------------------------
# ✅ Rankings procesados y combinados correctamente.

# %% [markdown]
# ---

# %%
df_time_series['country']
# Out:
# shape: (1_380, 13)
# ┌───────────┬──────────┬────────────┬───────────┬───┬───────────┬───────────┬──────────┬───────────┐
# │ Country   ┆ Region   ┆ Subregion  ┆ Dimension ┆ … ┆ homicides ┆ populatio ┆ Region_2 ┆ homicides │
# │ ---       ┆ ---      ┆ ---        ┆ ---       ┆   ┆ _count    ┆ n         ┆ ---      ┆ _rate_abs │
# │ str       ┆ str      ┆ str        ┆ str       ┆   ┆ ---       ┆ ---       ┆ str      ┆ _change   │
# │           ┆          ┆            ┆           ┆   ┆ f64       ┆ i64       ┆          ┆ ---       │
# │           ┆          ┆            ┆           ┆   ┆           ┆           ┆          ┆ f64       │
# ╞═══════════╪══════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪══════════╪═══════════╡
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 387.0     ┆ 21939310  ┆ Latam    ┆ null      │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 2450.0    ┆ 21537702  ┆ Latam    ┆ null      │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 1909.0    ┆ 21953153  ┆ Latam    ┆ -2.68     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 408.0     ┆ 22335741  ┆ Latam    ┆ 0.07      │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 396.0     ┆ 22512096  ┆ Latam    ┆ -0.07     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ …         ┆ …        ┆ …          ┆ …         ┆ … ┆ …         ┆ …         ┆ …        ┆ …         │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 14606.0   ┆ 15195272  ┆ Latam    ┆ -6.72     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 806.0     ┆ 15485244  ┆ Latam    ┆ 0.45      │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 16280.0   ┆ 15280476  ┆ Latam    ┆ 10.42     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 788.0     ┆ 15396408  ┆ Latam    ┆ -0.08     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 13662.0   ┆ 15168916  ┆ Latam    ┆ -16.47    │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# └───────────┴──────────┴────────────┴───────────┴───┴───────────┴───────────┴──────────┴───────────┘

# %%
df_time_series['region']
# Out:
# shape: (318, 4)
# ┌──────────┬──────┬────────┬─────────────────────┐
# │ Region_2 ┆ Year ┆ Sex    ┆ mean_homicides_rate │
# │ ---      ┆ ---  ┆ ---    ┆ ---                 │
# │ str      ┆ i64  ┆ str    ┆ f64                 │
# ╞══════════╪══════╪════════╪═════════════════════╡
# │ Asia     ┆ 1990 ┆ Female ┆ 0.49                │
# │ Asia     ┆ 1990 ┆ Male   ┆ 0.61                │
# │ Asia     ┆ 1991 ┆ Female ┆ 0.47                │
# │ Asia     ┆ 1991 ┆ Male   ┆ 0.56                │
# │ Asia     ┆ 1992 ┆ Female ┆ 0.48                │
# │ …        ┆ …    ┆ …      ┆ …                   │
# │ USA      ┆ 2021 ┆ Male   ┆ 10.51               │
# │ USA      ┆ 2022 ┆ Female ┆ 2.81                │
# │ USA      ┆ 2022 ┆ Male   ┆ 10.18               │
# │ USA      ┆ 2023 ┆ Female ┆ 2.55                │
# │ USA      ┆ 2023 ┆ Male   ┆ 8.94                │
# └──────────┴──────┴────────┴─────────────────────┘

# %%
df_ranking_combined['country']
# Out:
# shape: (170, 5)
# ┌─────────────┬────────┬─────────────────────┬──────────┬───────────┐
# │ Country     ┆ Sex    ┆ mean_homicides_rate ┆ Region_2 ┆ Periodo   │
# │ ---         ┆ ---    ┆ ---                 ┆ ---      ┆ ---       │
# │ str         ┆ str    ┆ f64                 ┆ str      ┆ str       │
# ╞═════════════╪════════╪═════════════════════╪══════════╪═══════════╡
# │ Japan       ┆ Female ┆ 0.41                ┆ Asia     ┆ 1990-2023 │
# │ Japan       ┆ Male   ┆ 0.45                ┆ Asia     ┆ 1990-2023 │
# │ Italy       ┆ Female ┆ 0.55                ┆ Europe   ┆ 1990-2023 │
# │ Spain       ┆ Female ┆ 0.57                ┆ Spain    ┆ 1990-2023 │
# │ Sweden      ┆ Female ┆ 0.61                ┆ Europe   ┆ 1990-2023 │
# │ …           ┆ …      ┆ …                   ┆ …        ┆ …         │
# │ Chile       ┆ Male   ┆ 10.13               ┆ Latam    ┆ 2019-2023 │
# │ Brazil      ┆ Male   ┆ 37.34               ┆ Latam    ┆ 2019-2023 │
# │ El Salvador ┆ Male   ┆ 39.42               ┆ Latam    ┆ 2019-2023 │
# │ Colombia    ┆ Male   ┆ 45.49               ┆ Latam    ┆ 2019-2023 │
# │ Mexico      ┆ Male   ┆ 49.37               ┆ Latam    ┆ 2019-2023 │
# └─────────────┴────────┴─────────────────────┴──────────┴───────────┘

# %%
df_ranking_combined['region']
# Out:
# shape: (44, 4)
# ┌──────────┬────────┬─────────────────────┬───────────┐
# │ Region_2 ┆ Sex    ┆ mean_homicides_rate ┆ Periodo   │
# │ ---      ┆ ---    ┆ ---                 ┆ ---       │
# │ str      ┆ str    ┆ f64                 ┆ str       │
# ╞══════════╪════════╪═════════════════════╪═══════════╡
# │ Spain    ┆ Female ┆ 0.57                ┆ 1990-2023 │
# │ Europe   ┆ Female ┆ 0.78                ┆ 1990-2023 │
# │ Spain    ┆ Male   ┆ 1.17                ┆ 1990-2023 │
# │ Asia     ┆ Female ┆ 1.6                 ┆ 1990-2023 │
# │ Europe   ┆ Male   ┆ 1.69                ┆ 1990-2023 │
# │ …        ┆ …      ┆ …                   ┆ …         │
# │ USA      ┆ Female ┆ 2.62                ┆ 2019-2023 │
# │ Latam    ┆ Female ┆ 3.44                ┆ 2019-2023 │
# │ Africa   ┆ Male   ┆ 3.7                 ┆ 2019-2023 │
# │ USA      ┆ Male   ┆ 9.49                ┆ 2019-2023 │
# │ Latam    ┆ Male   ┆ 31.63               ┆ 2019-2023 │
# └──────────┴────────┴─────────────────────┴───────────┘

# %% [markdown]
# ---

# %% [markdown]
# ## Time Series

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate',
    line_group='Country',
    facet_col='Sex',
    color='Country',
    default_visible_name='Spain',
    title='Evolución de la Tasa de Homicidios Intencionados en el Mundo por Sexo (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate',
    line_group='Country',
    facet_col='Sex',
    color='Region_2',
    default_visible_name='Spain',
    title='Evolución de la Tasa de Homicidios Intencionados en el Mundo por Región y Sexo (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate',
    line_group='Country',
    line_dash='Sex',
    color='Region_2',
    default_visible_name=['Spain, Female', 'Spain, Male'],
    title='Evolución de la Tasa de Homicidios por Región y Sexo (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['region'],
    x='Year',
    y='mean_homicides_rate',
    line_group='Region_2',
    facet_col='Sex',
    color='Region_2',
    default_visible_name='Spain',
    title='Evolución de la Tasa Media de Homicidios Intencionados en el Mundo por Región y Sexo (1990-2023)',
    hover_data=HOVER_DATA['time_series_region'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_region'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['region'],
    x='Year',
    y='mean_homicides_rate',
    line_group='Region_2',
    line_dash='Sex',
    color='Region_2',
    default_visible_name=['Spain, Female', 'Spain, Male'],
    title='Evolución de la Tasa de Homicidios por Región y Sexo (1990-2023)',
    hover_data=HOVER_DATA['time_series_region'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_region'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %% [markdown]
# ## Rankings

# %%
barplot(
    df = df_ranking_combined['country'], 
    x='mean_homicides_rate', 
    y='Country', 
    height=2000,
    reverse_y_order=False,
    orientation='h', 
    color='Sex', 
    facet_col='Periodo',
    cols_wrap=1, 
    vertical_spacing = 0.01,
    #barmode='group',
    yticks_color_column='Region_2',
    yticks_color_map=COLOR_MAP['Region_2'],
    color_discrete_map=COLOR_MAP['Sex'], 
    #category_orders=CATEGORY_ORDERS,
    hover_data=HOVER_DATA['ranking_country'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_country'],
    title=f"Ranking de Homicidios por Pais y Sexo",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_country']), 
    show=True
    )

# %%
barplot(
    df = df_ranking_combined['country'], 
    x='mean_homicides_rate', 
    y='Country', 
    height=1000,
    reverse_y_order=False,
    orientation='h', 
    color='Sex', 
    facet_col='Periodo',
    cols_wrap=2, 
    vertical_spacing = 0.03,
    #barmode='group',
    yticks_color_column='Region_2',
    yticks_color_map=COLOR_MAP['Region_2'],
    color_discrete_map=COLOR_MAP['Sex'], 
    #category_orders=CATEGORY_ORDERS,
    hover_data=HOVER_DATA['ranking_country'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_country'],
    title=f"Ranking Mundial de Homicidios por País",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots',  PLOT_FILENAME['ranking_country']), 
    show=True
    )

# %%
barplot(
    df = df_ranking_combined['region'], 
    x='mean_homicides_rate', 
    y='Region_2', 
    height=800,
    reverse_y_order=False,
    orientation='h', 
    color='Sex', 
    facet_col='Periodo',
    cols_wrap=1, 
    vertical_spacing = 0.03,
    #barmode='group',
    yticks_color_column='Region_2',
    yticks_color_map=COLOR_MAP['Region_2'],
    color_discrete_map=COLOR_MAP['Sex'], 
    #category_orders=CATEGORY_ORDERS,
    hover_data=HOVER_DATA['ranking_region'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_region'],
    title=f"Ranking Mundial de Homicidios por País",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_region']), 
    show=True
    )

# %%
barplot(
    df = df_ranking_combined['region'], 
    x='mean_homicides_rate', 
    y='Region_2', 
    height=800,
    reverse_y_order=False,
    orientation='h', 
    color='Sex', 
    facet_col='Periodo',
    cols_wrap=2, 
    vertical_spacing = 0.03,
    barmode='group',
    yticks_color_column='Region_2',
    yticks_color_map=COLOR_MAP['Region_2'],
    color_discrete_map=COLOR_MAP['Sex'], 
    #category_orders=CATEGORY_ORDERS,
    hover_data=HOVER_DATA['ranking_region'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_region'],
    title=f"Ranking Mundial de Homicidios por País",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_region']), 
    show=True
    )
