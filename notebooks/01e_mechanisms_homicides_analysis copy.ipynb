# %% [markdown]
# # Homicides by Mechanism (Dimension) Data Analysis

# %% [markdown]
# ## TO DO

# %% [markdown]
# ## Requirements

# %%
import os, sys
import polars as pl
import numpy as np

# %%
SCRIPT_PATH = os.getcwd() # os.path.dirname(os.path.abspath(__file__))
PROJECT_PATH = os.path.join(SCRIPT_PATH, '..')
INPUT_DIR = os.path.join(PROJECT_PATH, 'data', 'processed')
INPUT_FILE = os.path.join(INPUT_DIR, 'processed_unodc_intentional_homicide_rate.csv')
PLOTS_PATH = os.path.join(PROJECT_PATH, 'plots')
os.makedirs(PLOTS_PATH, exist_ok=True)

# %%
sys.path.append(PROJECT_PATH)

from config.config_01a import (
    SELECTED_COUNTRIES, 
    COLOR_MAP, 
    CATEGORY_ORDERS,
    HOVER_DATA,
    LABELS, 
    HOVER_TEMPLATES,
    PLOT_FILENAME,
    PROP_YEARS_IN_PERIOD_LIMIT,
    REF_REGION_FOR_START_YEAR
)

from src.plots_utils import time_series_plot, barplot
from src.analysis_utils import process_time_series_data, process_ranking_data

# %%
df['Dimension'].unique().to_list()
# Out:
# ['by mechanisms',
#  'by relationship to perpetrator',
#  'by situational context',
#  'Total']

# %%
# Read data
df = pl.read_csv(INPUT_FILE)

# %%
# Processing for time series by country and region

by = 'Category'
dimension = 'by mechanisms'


df_time_series, optimal_min_year, max_year = process_time_series_data(
    df = df, 
    selected_countries = SELECTED_COUNTRIES, 
    prop_years_in_period_limit = PROP_YEARS_IN_PERIOD_LIMIT, 
    ref_region_for_start_year = REF_REGION_FOR_START_YEAR,
    by = by,
    dimension=dimension
    )
# Out:
# ⚙️ Procesando desglose por: CATEGORY
# --------------------------------------------------------------------------------
# 📊 Paises SIN datos de este tipo:
#    - Número: 12 de 31
#    - Lista: ['Portugal', 'Sweden', 'Norway', 'Denmark', 'Romania', 'Mexico', 'China', 'India', 'Indonesia', 'Thailand', 'Türkiye', 'South Africa']
# --------------------------------------------------------------------------------
# 📅 Periodo para región: 2015-2023
# ✅ Países válidos para región: 7 de 31
# --------------------------------------------------------------------------------

# %%
# Processing for Rankings by country and region

initial_years = [
    optimal_min_year, # 2015
    2019, 
    2021
]

df_ranking_combined, df_ranking_dict = process_ranking_data(
    df = df_time_series['country'], 
    selected_countries = SELECTED_COUNTRIES, 
    prop_years_in_period_limit = PROP_YEARS_IN_PERIOD_LIMIT, 
    initial_years = initial_years, 
    max_year = max_year,
    by = by
)
# Out:
# 🔄 Procesando ranking (Category) para: 2015-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 2015 - 2023
#    Segmentado por: Category
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 7
#    Países descartados: ['Portugal', 'United Kingdom', 'Sweden', 'Norway', 'Denmark', 'Romania', 'Greece', 'Brazil', 'Mexico', 'Colombia', 'Venezuela', 'Argentina', 'Chile', 'Republic of Korea', 'Singapore', 'China', 'India', 'Philippines', 'Indonesia', 'Thailand', 'Türkiye', 'Morocco', 'Egypt', 'South Africa']
#    Prop. datos (años) en el periodo, por pais: {'Japan': 0.67, 'Argentina': 0.44, 'United Kingdom': 0.44, 'Colombia': 0.11, 'El Salvador': 0.78, 'France': 1.0, 'Germany': 1.0, 'Venezuela': 0.22, 'Chile': 0.56, 'Spain': 0.89, 'Italy': 1.0, 'Brazil': 0.44, 'Philippines': 0.44, 'USA': 0.67, 'Greece': 0.33, 'Morocco': 0.56, 'Portugal': 0.0, 'Sweden': 0.0, 'Norway': 0.0, 'Denmark': 0.0, 'Romania': 0.0, 'Mexico': 0.0, 'Republic of Korea': 0.0, 'Singapore': 0.0, 'China': 0.0, 'India': 0.0, 'Indonesia': 0.0, 'Thailand': 0.0, 'Türkiye': 0.0, 'Egypt': 0.0, 'South Africa': 0.0}
# ----------------------------------------------------------------------------------------------------
# 🔄 Procesando ranking (Category) para: 2019-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 2019 - 2023
#    Segmentado por: Category
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 10
#    Países descartados: ['Portugal', 'United Kingdom', 'Sweden', 'Norway', 'Denmark', 'Romania', 'Greece', 'Mexico', 'Venezuela', 'Republic of Korea', 'Singapore', 'China', 'India', 'Philippines', 'Indonesia', 'Thailand', 'Türkiye', 'Morocco', 'Egypt', 'South Africa', 'USA']
#    Prop. datos (años) en el periodo, por pais: {'Argentina': 0.8, 'USA': 0.4, 'Philippines': 0.2, 'Spain': 1.0, 'El Salvador': 0.8, 'Japan': 0.8, 'Italy': 1.0, 'United Kingdom': 0.2, 'Morocco': 0.6, 'Greece': 0.6, 'Germany': 1.0, 'Chile': 1.0, 'France': 1.0, 'Brazil': 0.8, 'Colombia': 1.0, 'Portugal': 0.0, 'Sweden': 0.0, 'Norway': 0.0, 'Denmark': 0.0, 'Romania': 0.0, 'Mexico': 0.0, 'Venezuela': 0.0, 'Republic of Korea': 0.0, 'Singapore': 0.0, 'China': 0.0, 'India': 0.0, 'Indonesia': 0.0, 'Thailand': 0.0, 'Türkiye': 0.0, 'Egypt': 0.0, 'South Africa': 0.0}
# ----------------------------------------------------------------------------------------------------
# 🔄 Procesando ranking (Category) para: 2021-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 2021 - 2023
#    Segmentado por: Category
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 13
#    Países descartados: ['Portugal', 'United Kingdom', 'Sweden', 'Norway', 'Denmark', 'Romania', 'Mexico', 'Venezuela', 'Republic of Korea', 'Singapore', 'China', 'India', 'Philippines', 'Indonesia', 'Thailand', 'Türkiye', 'Egypt', 'South Africa']
#    Prop. datos (años) en el periodo, por pais: {'USA': 1.0, 'Greece': 1.0, 'Argentina': 1.0, 'Colombia': 1.0, 'Italy': 1.0, 'El Salvador': 0.67, 'Morocco': 0.67, 'Chile': 1.0, 'Japan': 1.0, 'Brazil': 1.0, 'Germany': 1.0, 'United Kingdom': 0.33, 'France': 1.0, 'Spain': 1.0, 'Philippines': 0.33, 'Portugal': 0.0, 'Sweden': 0.0, 'Norway': 0.0, 'Denmark': 0.0, 'Romania': 0.0, 'Mexico': 0.0, 'Venezuela': 0.0, 'Republic of Korea': 0.0, 'Singapore': 0.0, 'China': 0.0, 'India': 0.0, 'Indonesia': 0.0, 'Thailand': 0.0, 'Türkiye': 0.0, 'Egypt': 0.0, 'South Africa': 0.0}
# ----------------------------------------------------------------------------------------------------
# ✅ Rankings procesados y combinados correctamente.

# %% [markdown]
# ---

# %%
df_time_series['country']
# Out:
# shape: (526, 13)
# ┌────────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬──────────┬───────────┐
# │ Country    ┆ Region   ┆ Subregion ┆ Dimension ┆ … ┆ homicides ┆ populatio ┆ Region_2 ┆ homicides │
# │ ---        ┆ ---      ┆ ---       ┆ ---       ┆   ┆ _count    ┆ n         ┆ ---      ┆ _rate_abs │
# │ str        ┆ str      ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ str      ┆ _change   │
# │            ┆          ┆           ┆           ┆   ┆ f64       ┆ i64       ┆          ┆ ---       │
# │            ┆          ┆           ┆           ┆   ┆           ┆           ┆          ┆ f64       │
# ╞════════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪══════════╪═══════════╡
# │ Argentina  ┆ Americas ┆ Latin     ┆ by situat ┆ … ┆ 453.0     ┆ 43477012  ┆ Latam    ┆ null      │
# │            ┆          ┆ America   ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ and the   ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ Caribbea… ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina  ┆ Americas ┆ Latin     ┆ by situat ┆ … ┆ 460.0     ┆ 44288894  ┆ Latam    ┆ 0.0       │
# │            ┆          ┆ America   ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ and the   ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ Caribbea… ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina  ┆ Americas ┆ Latin     ┆ by situat ┆ … ┆ 442.0     ┆ 44654882  ┆ Latam    ┆ -0.05     │
# │            ┆          ┆ America   ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ and the   ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ Caribbea… ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina  ┆ Americas ┆ Latin     ┆ by situat ┆ … ┆ 444.0     ┆ 44973466  ┆ Latam    ┆ 0.0       │
# │            ┆          ┆ America   ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ and the   ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ Caribbea… ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina  ┆ Americas ┆ Latin     ┆ by situat ┆ … ┆ 868.0     ┆ 45191964  ┆ Latam    ┆ null      │
# │            ┆          ┆ America   ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ and the   ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ Caribbea… ┆           ┆   ┆           ┆           ┆          ┆           │
# │ …          ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …        ┆ …         │
# │ United     ┆ Europe   ┆ Northern  ┆ by situat ┆ … ┆ 370.0     ┆ 59597546  ┆ Europe   ┆ 0.02      │
# │ Kingdom    ┆          ┆ Europe    ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆           ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │ United     ┆ Europe   ┆ Northern  ┆ by situat ┆ … ┆ 133.0     ┆ 59597546  ┆ Europe   ┆ 0.0       │
# │ Kingdom    ┆          ┆ Europe    ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆           ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │ United     ┆ Europe   ┆ Northern  ┆ by situat ┆ … ┆ 1.0       ┆ 59597546  ┆ Europe   ┆ 0.0       │
# │ Kingdom    ┆          ┆ Europe    ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆           ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela  ┆ Americas ┆ Latin     ┆ by situat ┆ … ┆ 2.0       ┆ 30565324  ┆ Latam    ┆ null      │
# │            ┆          ┆ America   ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ and the   ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ Caribbea… ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela  ┆ Americas ┆ Latin     ┆ by situat ┆ … ┆ 47.0      ┆ 29807592  ┆ Latam    ┆ 0.15      │
# │            ┆          ┆ America   ┆ ional     ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ and the   ┆ context   ┆   ┆           ┆           ┆          ┆           │
# │            ┆          ┆ Caribbea… ┆           ┆   ┆           ┆           ┆          ┆           │
# └────────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴──────────┴───────────┘

# %%
df_time_series['region']
# Out:
# shape: (240, 4)
# ┌──────────┬──────┬─────────────────────────────────┬─────────────────────┐
# │ Region_2 ┆ Year ┆ Category                        ┆ mean_homicides_rate │
# │ ---      ┆ ---  ┆ ---                             ┆ ---                 │
# │ str      ┆ i64  ┆ str                             ┆ f64                 │
# ╞══════════╪══════╪═════════════════════════════════╪═════════════════════╡
# │ Asia     ┆ 2005 ┆ Other criminal activities       ┆ 0.03                │
# │ Asia     ┆ 2006 ┆ Other criminal activities       ┆ 0.03                │
# │ Asia     ┆ 2007 ┆ Other criminal activities       ┆ 0.02                │
# │ Asia     ┆ 2008 ┆ Other criminal activities       ┆ 0.02                │
# │ Asia     ┆ 2009 ┆ Other criminal activities       ┆ 0.03                │
# │ …        ┆ …    ┆ …                               ┆ …                   │
# │ USA      ┆ 2020 ┆ Socio-political homicide        ┆ 0.01                │
# │ USA      ┆ 2020 ┆ Unknown types of homicide       ┆ 3.08                │
# │ USA      ┆ 2021 ┆ Organized criminal groups or g… ┆ 0.15                │
# │ USA      ┆ 2022 ┆ Organized criminal groups or g… ┆ 0.17                │
# │ USA      ┆ 2023 ┆ Organized criminal groups or g… ┆ 0.12                │
# └──────────┴──────┴─────────────────────────────────┴─────────────────────┘

# %%
df_ranking_combined['country']
# Out:
# shape: (112, 5)
# ┌─────────────┬─────────────────────────────────┬─────────────────────┬──────────┬───────────┐
# │ Country     ┆ Category                        ┆ mean_homicides_rate ┆ Region_2 ┆ Periodo   │
# │ ---         ┆ ---                             ┆ ---                 ┆ ---      ┆ ---       │
# │ str         ┆ str                             ┆ f64                 ┆ str      ┆ str       │
# ╞═════════════╪═════════════════════════════════╪═════════════════════╪══════════╪═══════════╡
# │ Japan       ┆ Other criminal activities       ┆ 0.01                ┆ Asia     ┆ 2015-2023 │
# │ Spain       ┆ Other criminal activities       ┆ 0.01                ┆ Spain    ┆ 2015-2023 │
# │ USA         ┆ Socio-political homicide        ┆ 0.01                ┆ USA      ┆ 2015-2023 │
# │ Spain       ┆ terrorist homicide              ┆ 0.01                ┆ Spain    ┆ 2015-2023 │
# │ Spain       ┆ Organized criminal groups or g… ┆ 0.01                ┆ Spain    ┆ 2015-2023 │
# │ …           ┆ …                               ┆ …                   ┆ …        ┆ …         │
# │ El Salvador ┆ terrorist homicide              ┆ NaN                 ┆ Latam    ┆ 2021-2023 │
# │ Greece      ┆ Organized criminal groups or g… ┆ NaN                 ┆ Europe   ┆ 2021-2023 │
# │ Greece      ┆ Socio-political homicide        ┆ NaN                 ┆ Europe   ┆ 2021-2023 │
# │ Greece      ┆ terrorist homicide              ┆ NaN                 ┆ Europe   ┆ 2021-2023 │
# │ El Salvador ┆ Unknown types of homicide       ┆ NaN                 ┆ Latam    ┆ 2021-2023 │
# └─────────────┴─────────────────────────────────┴─────────────────────┴──────────┴───────────┘

# %%
df_ranking_combined['region']
# Out:
# shape: (65, 4)
# ┌──────────┬─────────────────────────────────┬─────────────────────┬───────────┐
# │ Region_2 ┆ Category                        ┆ mean_homicides_rate ┆ Periodo   │
# │ ---      ┆ ---                             ┆ ---                 ┆ ---       │
# │ str      ┆ str                             ┆ f64                 ┆ str       │
# ╞══════════╪═════════════════════════════════╪═════════════════════╪═══════════╡
# │ Spain    ┆ Other criminal activities       ┆ 0.01                ┆ 2015-2023 │
# │ Spain    ┆ terrorist homicide              ┆ 0.01                ┆ 2015-2023 │
# │ USA      ┆ Socio-political homicide        ┆ 0.01                ┆ 2015-2023 │
# │ Asia     ┆ Other criminal activities       ┆ 0.01                ┆ 2015-2023 │
# │ Spain    ┆ Organized criminal groups or g… ┆ 0.01                ┆ 2015-2023 │
# │ …        ┆ …                               ┆ …                   ┆ …         │
# │ Europe   ┆ terrorist homicide              ┆ NaN                 ┆ 2021-2023 │
# │ Europe   ┆ Organized criminal groups or g… ┆ NaN                 ┆ 2021-2023 │
# │ Latam    ┆ Unknown types of homicide       ┆ NaN                 ┆ 2021-2023 │
# │ Europe   ┆ Socio-political homicide        ┆ NaN                 ┆ 2021-2023 │
# │ Latam    ┆ terrorist homicide              ┆ NaN                 ┆ 2021-2023 │
# └──────────┴─────────────────────────────────┴─────────────────────┴───────────┘

# %% [markdown]
# ---

# %% [markdown]
# ## Time Series

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate',
    line_group='Country',
    facet_col='Category',
    facet_col_wrap=3,
    color='Country',
    default_visible_name='Spain',
    title='Evolución de la Tasa de Homicidios Intencionados en el Mundo por Edad (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate',
    line_group='Country',
    facet_col='Category',
    facet_col_wrap=3,
    color='Region_2',
    default_visible_name='Spain',
    title='Evolución de la Tasa de Homicidios Intencionados en el Mundo por Región y Edad (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate',
    line_group='Country',
    line_dash='Category',
    color='Region_2',
    default_visible_name=['Spain, Interpersonal homicide', 'Spain, Other criminal activities'],
    title='Evolución de la Tasa de Homicidios por Región y Edad (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['region'],
    x='Year',
    y='mean_homicides_rate',
    line_group='Region_2',
    facet_col='Category',
    facet_col_wrap=3,
    color='Region_2',
    default_visible_name='Spain',
    title='Evolución de la Tasa Media de Homicidios Intencionados en el Mundo por Región y Edad (1990-2023)',
    hover_data=HOVER_DATA['time_series_region'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_region'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %% [markdown]
# ## Rankings

# %%
barplot(
    df = df_ranking_combined['country'], 
    x='mean_homicides_rate', 
    y='Country', 
    height=2000,
    reverse_y_order=False,
    orientation='h', 
    color='Category', 
    barmode='group',
    facet_col='Periodo',
    cols_wrap=1, 
    vertical_spacing = 0.01,
    yticks_color_column='Region_2',
    yticks_color_map=COLOR_MAP['Region_2'],
    #color_discrete_map=COLOR_MAP['Age'], 
    #category_orders=CATEGORY_ORDERS,
    hover_data=HOVER_DATA['ranking_country'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_country'],
    title=f"Ranking Mundial de Homicidios por País",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_country']), 
    show=True
    )

# %%
barplot(
    df = df_ranking_combined['country'], 
    x='mean_homicides_rate', 
    y='Country', 
    height=1000,
    reverse_y_order=False,
    orientation='h', 
    color='Category', 
    facet_col='Periodo',
    cols_wrap=2, 
    vertical_spacing = 0.02,
    barmode='group',
    yticks_color_column='Region_2',
    yticks_color_map=COLOR_MAP['Region_2'],
    color_discrete_map=COLOR_MAP['Sex'], 
    #category_orders=CATEGORY_ORDERS,
    hover_data=HOVER_DATA['ranking_country'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_country'],
    title=f"Ranking Mundial de Homicidios por País",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_country']), 
    show=True
    )

# %%
barplot(
    df = df_ranking_combined['region'], 
    x='mean_homicides_rate', 
    y='Region_2', 
    height=800,
    reverse_y_order=False,
    orientation='h', 
    color='Category', 
    facet_col='Periodo',
    cols_wrap=1, 
    vertical_spacing = 0.01,
    barmode='group',
    yticks_color_column='Region_2',
    yticks_color_map=COLOR_MAP['Region_2'],
    color_discrete_map=COLOR_MAP['Sex'], 
    #category_orders=CATEGORY_ORDERS,
    hover_data=HOVER_DATA['ranking_region'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_region'],
    title=f"Ranking Mundial de Homicidios por País",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_region']), 
    show=True
    )

# %%
barplot(
    df = df_ranking_combined['region'], 
    x='mean_homicides_rate', 
    y='Region_2', 
    height=800,
    reverse_y_order=False,
    orientation='h', 
    color='Category', 
    facet_col='Periodo',
    cols_wrap=2, 
    vertical_spacing = 0.01,
    barmode='group',
    yticks_color_column='Region_2',
    yticks_color_map=COLOR_MAP['Region_2'],
    color_discrete_map=COLOR_MAP['Sex'], 
    #category_orders=CATEGORY_ORDERS,
    hover_data=HOVER_DATA['ranking_region'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_region'],
    title=f"Ranking Mundial de Homicidios por País",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_region']), 
    show=True
    )
