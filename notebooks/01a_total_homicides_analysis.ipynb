# %% [markdown]
# # Total Homicides Data Analysis

# %% [markdown]
# ## Requirements

# %%
import os, sys
import polars as pl
import numpy as np

# %%
SCRIPT_PATH = os.getcwd() # os.path.dirname(os.path.abspath(__file__))
PROJECT_PATH = os.path.join(SCRIPT_PATH, '..')
INPUT_DIR = os.path.join(PROJECT_PATH, 'data', 'processed')
INPUT_FILE = os.path.join(INPUT_DIR, 'processed_unodc_intentional_homicide_rate.csv')
PLOTS_PATH = os.path.join(PROJECT_PATH, 'plots')
os.makedirs(PLOTS_PATH, exist_ok=True)

# %%
sys.path.append(PROJECT_PATH)

from config.config_01a import (
    SELECTED_COUNTRIES, 
    COLOR_MAP, 
    CATEGORY_ORDERS,
    HOVER_DATA,
    LABELS, 
    HOVER_TEMPLATES,
    PLOT_FILENAME,
    PROP_YEARS_IN_PERIOD_LIMIT,
    REF_REGION_FOR_START_YEAR
)

from src.plots_utils import time_series_plot, barplot
from src.analysis_utils import process_time_series_data, process_ranking_data

# %%
# Read data
df = pl.read_csv(INPUT_FILE)

# %%
# Processing for time series by country and region

df_time_series, optimal_min_year, max_year = process_time_series_data(
    df = df, 
    selected_countries = SELECTED_COUNTRIES, 
    prop_years_in_period_limit = PROP_YEARS_IN_PERIOD_LIMIT, 
    ref_region_for_start_year = REF_REGION_FOR_START_YEAR)
# Out:
# ⚙️ Procesando serie: TOTAL PAÍS
# 📅 Periodo: 1998-2023
# ✅ Países válidos para región: 27 de 31
# --------------------------------------------------------------------------------

# %%
# Processing for Rankings by country and region

initial_years = [1990, 
                 optimal_min_year,# 1998
                 2014,
                 2019]

df_ranking_combined, df_ranking_dict = process_ranking_data(
    df = df_time_series['country'], 
    selected_countries = SELECTED_COUNTRIES, 
    prop_years_in_period_limit = PROP_YEARS_IN_PERIOD_LIMIT, 
    initial_years = initial_years, 
    max_year = max_year
)
# Out:
# 🔄 Procesando ranking (Total) para: 1990-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 1990 - 2023
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 26
#    Países descartados: ['Chile', 'Philippines', 'Indonesia', 'Türkiye', 'Egypt']
#    Prop. datos (años) en el periodo, por pais: {'China': 0.65, 'Germany': 1.0, 'Romania': 1.0, 'Japan': 1.0, 'Chile': 0.59, 'Brazil': 1.0, 'Thailand': 0.65, 'Argentina': 0.68, 'Norway': 0.97, 'Spain': 1.0, 'Italy': 0.94, 'Philippines': 0.62, 'United Kingdom': 0.91, 'Greece': 0.94, 'USA': 0.91, 'Morocco': 0.94, 'Colombia': 1.0, 'Mexico': 1.0, 'Sweden': 1.0, 'Türkiye': 0.53, 'France': 1.0, 'Singapore': 0.97, 'Denmark': 0.79, 'El Salvador': 0.85, 'Indonesia': 0.18, 'Venezuela': 0.91, 'Egypt': 0.56, 'India': 0.97, 'Portugal': 0.79, 'South Africa': 0.85, 'Republic of Korea': 1.0}
# ----------------------------------------------------------------------------------------------------
# 🔄 Procesando ranking (Total) para: 1998-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 1998 - 2023
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 27
#    Países descartados: ['Philippines', 'Indonesia', 'Thailand', 'Egypt']
#    Prop. datos (años) en el periodo, por pais: {'Norway': 0.96, 'Chile': 0.77, 'Republic of Korea': 1.0, 'Türkiye': 0.69, 'Brazil': 1.0, 'Thailand': 0.54, 'Mexico': 1.0, 'India': 0.96, 'Philippines': 0.62, 'Japan': 1.0, 'Argentina': 0.88, 'Germany': 1.0, 'Indonesia': 0.23, 'Italy': 0.92, 'Denmark': 0.73, 'Spain': 1.0, 'Sweden': 1.0, 'Colombia': 1.0, 'Egypt': 0.54, 'United Kingdom': 0.92, 'Romania': 1.0, 'Greece': 0.92, 'South Africa': 0.96, 'El Salvador': 0.96, 'USA': 0.88, 'Morocco': 1.0, 'China': 0.73, 'France': 1.0, 'Portugal': 0.73, 'Singapore': 0.96, 'Venezuela': 0.88}
# ----------------------------------------------------------------------------------------------------
# 🔄 Procesando ranking (Total) para: 2014-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 2014 - 2023
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 27
#    Países descartados: ['Philippines', 'Indonesia', 'Thailand', 'Egypt']
#    Prop. datos (años) en el periodo, por pais: {'USA': 1.0, 'Germany': 1.0, 'Norway': 1.0, 'China': 0.7, 'Brazil': 1.0, 'El Salvador': 0.9, 'France': 1.0, 'Sweden': 1.0, 'Japan': 1.0, 'Mexico': 1.0, 'Chile': 1.0, 'Türkiye': 0.9, 'South Africa': 0.9, 'Venezuela': 0.8, 'Denmark': 1.0, 'Egypt': 0.4, 'Portugal': 0.9, 'United Kingdom': 0.8, 'Morocco': 1.0, 'Singapore': 1.0, 'Greece': 1.0, 'Spain': 1.0, 'Republic of Korea': 1.0, 'Romania': 1.0, 'Indonesia': 0.1, 'Colombia': 1.0, 'Italy': 1.0, 'Argentina': 1.0, 'Philippines': 0.5, 'India': 0.9, 'Thailand': 0.0}
# ----------------------------------------------------------------------------------------------------
# 🔄 Procesando ranking (Total) para: 2019-2023
# ----------------------------------------------------------------------------------------------------
# 📊 Ranking Period: 2019 - 2023
#    Países analizados: 31
#    Países seleccionados (Data > 65.0%): 25
#    Países descartados: ['United Kingdom', 'China', 'Philippines', 'Indonesia', 'Thailand', 'Egypt']
#    Prop. datos (años) en el periodo, por pais: {'Denmark': 1.0, 'Republic of Korea': 1.0, 'United Kingdom': 0.6, 'South Africa': 0.8, 'Argentina': 1.0, 'Colombia': 1.0, 'Venezuela': 0.8, 'Indonesia': 0.2, 'El Salvador': 0.8, 'Romania': 1.0, 'Spain': 1.0, 'France': 1.0, 'India': 0.8, 'Türkiye': 1.0, 'China': 0.4, 'Morocco': 1.0, 'Norway': 1.0, 'Brazil': 1.0, 'Greece': 1.0, 'Mexico': 1.0, 'Sweden': 1.0, 'Germany': 1.0, 'Portugal': 0.8, 'Japan': 1.0, 'Philippines': 0.4, 'USA': 1.0, 'Chile': 1.0, 'Italy': 1.0, 'Singapore': 1.0, 'Thailand': 0.0, 'Egypt': 0.0}
# ----------------------------------------------------------------------------------------------------
# ✅ Rankings procesados y combinados correctamente.

# %% [markdown]
# ---

# %%
df_time_series['country']
# Out:
# shape: (891, 13)
# ┌───────────┬──────────┬────────────┬───────────┬───┬───────────┬───────────┬──────────┬───────────┐
# │ Country   ┆ Region   ┆ Subregion  ┆ Dimension ┆ … ┆ homicides ┆ populatio ┆ Region_2 ┆ homicides │
# │ ---       ┆ ---      ┆ ---        ┆ ---       ┆   ┆ _count    ┆ n         ┆ ---      ┆ _rate_abs │
# │ str       ┆ str      ┆ str        ┆ str       ┆   ┆ ---       ┆ ---       ┆ str      ┆ _change   │
# │           ┆          ┆            ┆           ┆   ┆ f64       ┆ i64       ┆          ┆ ---       │
# │           ┆          ┆            ┆           ┆   ┆           ┆           ┆          ┆ f64       │
# ╞═══════════╪══════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪══════════╪═══════════╡
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 3129.0    ┆ 37624826  ┆ Latam    ┆ null      │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 3570.0    ┆ 38029349  ┆ Latam    ┆ 1.07      │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 2967.0    ┆ 38424282  ┆ Latam    ┆ -1.67     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 2338.0    ┆ 38815915  ┆ Latam    ┆ -1.7      │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Argentina ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 2198.0    ┆ 39216790  ┆ Latam    ┆ -0.42     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ …         ┆ …        ┆ …          ┆ …         ┆ … ┆ …         ┆ …         ┆ …        ┆ …         │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 14665.0   ┆ 30565324  ┆ Latam    ┆ -8.6      │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 11874.0   ┆ 28938098  ┆ Latam    ┆ -6.95     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 8384.0    ┆ 28444077  ┆ Latam    ┆ -11.55    │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 5444.0    ┆ 28237826  ┆ Latam    ┆ -10.2     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# │ Venezuela ┆ Americas ┆ Latin      ┆ Total     ┆ … ┆ 3568.0    ┆ 28213016  ┆ Latam    ┆ -6.63     │
# │           ┆          ┆ America    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ and the    ┆           ┆   ┆           ┆           ┆          ┆           │
# │           ┆          ┆ Caribbea…  ┆           ┆   ┆           ┆           ┆          ┆           │
# └───────────┴──────────┴────────────┴───────────┴───┴───────────┴───────────┴──────────┴───────────┘

# %%
df_time_series['region']
# Out:
# shape: (201, 3)
# ┌──────────┬──────┬─────────────────────┐
# │ Region_2 ┆ Year ┆ mean_homicides_rate │
# │ ---      ┆ ---  ┆ ---                 │
# │ str      ┆ i64  ┆ f64                 │
# ╞══════════╪══════╪═════════════════════╡
# │ Africa   ┆ 1990 ┆ 0.37                │
# │ Africa   ┆ 1991 ┆ 0.5                 │
# │ Africa   ┆ 1992 ┆ 0.52                │
# │ Africa   ┆ 1993 ┆ 0.58                │
# │ Africa   ┆ 1994 ┆ 37.35               │
# │ …        ┆ …    ┆ …                   │
# │ USA      ┆ 2019 ┆ 4.93                │
# │ USA      ┆ 2020 ┆ 6.35                │
# │ USA      ┆ 2021 ┆ 6.78                │
# │ USA      ┆ 2022 ┆ 6.51                │
# │ USA      ┆ 2023 ┆ 5.76                │
# └──────────┴──────┴─────────────────────┘

# %%
df_ranking_combined['country']
# Out:
# shape: (105, 4)
# ┌───────────────────┬─────────────────────┬──────────┬───────────┐
# │ Country           ┆ mean_homicides_rate ┆ Region_2 ┆ Periodo   │
# │ ---               ┆ ---                 ┆ ---      ┆ ---       │
# │ str               ┆ f64                 ┆ str      ┆ str       │
# ╞═══════════════════╪═════════════════════╪══════════╪═══════════╡
# │ Japan             ┆ 0.43                ┆ Asia     ┆ 1990-2023 │
# │ Singapore         ┆ 0.56                ┆ Asia     ┆ 1990-2023 │
# │ Republic of Korea ┆ 0.71                ┆ Asia     ┆ 1990-2023 │
# │ Norway            ┆ 0.78                ┆ Europe   ┆ 1990-2023 │
# │ Spain             ┆ 0.95                ┆ Spain    ┆ 1990-2023 │
# │ …                 ┆ …                   ┆ …        ┆ …         │
# │ El Salvador       ┆ 21.29               ┆ Latam    ┆ 2019-2023 │
# │ Colombia          ┆ 24.31               ┆ Latam    ┆ 2019-2023 │
# │ Venezuela         ┆ 25.71               ┆ Latam    ┆ 2019-2023 │
# │ Mexico            ┆ 27.35               ┆ Latam    ┆ 2019-2023 │
# │ South Africa      ┆ 38.42               ┆ Africa   ┆ 2019-2023 │
# └───────────────────┴─────────────────────┴──────────┴───────────┘

# %%
df_ranking_combined['region']
# Out:
# shape: (24, 3)
# ┌──────────┬─────────────────────┬───────────┐
# │ Region_2 ┆ mean_homicides_rate ┆ Periodo   │
# │ ---      ┆ ---                 ┆ ---       │
# │ str      ┆ f64                 ┆ str       │
# ╞══════════╪═════════════════════╪═══════════╡
# │ Spain    ┆ 0.95                ┆ 1990-2023 │
# │ Europe   ┆ 1.26                ┆ 1990-2023 │
# │ Asia     ┆ 2.4                 ┆ 1990-2023 │
# │ USA      ┆ 6.12                ┆ 1990-2023 │
# │ Africa   ┆ 20.66               ┆ 1990-2023 │
# │ …        ┆ …                   ┆ …         │
# │ Europe   ┆ 0.88                ┆ 2019-2023 │
# │ Asia     ┆ 1.29                ┆ 2019-2023 │
# │ USA      ┆ 6.07                ┆ 2019-2023 │
# │ Latam    ┆ 18.53               ┆ 2019-2023 │
# │ Africa   ┆ 20.3                ┆ 2019-2023 │
# └──────────┴─────────────────────┴───────────┘

# %% [markdown]
# ---

# %% [markdown]
# ## Time Series

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate',
    color='Country',
    default_visible_name='Spain',
    title='Evolución de la Tasa de Homicidios Intencionados en el Mundo (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate_abs_change',
    color='Country',
    default_visible_name='Spain',
    title='Evolución de la Variación Absoluta de la Tasa de Homicidios Intencionados en el Mundo (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate',
    line_group='Country',
    color='Region_2',
    default_visible_name='Spain',
    title='Evolución de la Tasa de Homicidios Intencionados en el Mundo por Región (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['country'],
    x='Year',
    y='homicides_rate_abs_change',
    line_group='Country',
    color='Region_2',
    default_visible_name='Spain',
    title='Evolución de la Variación Absoluta de la Tasa de Homicidios Intencionados en el Mundo por Región (1990-2023)',
    hover_data=HOVER_DATA['time_series_country'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_country'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %%
time_series_plot(
    df = df_time_series['region'],
    x='Year',
    y='mean_homicides_rate',
    line_group='Region_2',
    color='Region_2',
    default_visible_name='Spain',
    title='Evolución de la Tasa Media de Homicidios Intencionados en el Mundo por Región (1990-2023)',
    hover_data=HOVER_DATA['time_series_region'],
    labels=LABELS['time_series'],
    hovertemplate=HOVER_TEMPLATES['time_series_region'],
    color_discrete_map=COLOR_MAP['Region_2'],
    category_orders=CATEGORY_ORDERS,
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['time_series']),
    show=True
)

# %% [markdown]
# ## Rankings

# %%
barplot(
    df = df_ranking_combined['country'], 
    x='mean_homicides_rate', 
    y='Country', 
    height=1000,
    orientation='h', 
    color='Region_2',
    facet_col='Periodo',
    cols_wrap=2, 
    barmode='relative',
    color_discrete_map=COLOR_MAP['Region_2'], 
    hover_data=HOVER_DATA['ranking_country'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_country'],
    title=f"Ranking Mundial de Homicidios por País",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_country']), 
    show=True
    )

# %%
barplot(
    df = df_ranking_combined['country'], 
    x='mean_homicides_rate', 
    y='Country', 
    height=2000,
    orientation='h', 
    color='Region_2',
    facet_col='Periodo',
    cols_wrap=1, 
    barmode='relative',
    vertical_spacing = 0.01,
    color_discrete_map=COLOR_MAP['Region_2'], 
    hover_data=HOVER_DATA['ranking_country'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_country'],
    title=f"Ranking Mundial de Homicidios por País para diferentes Periodos",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_country']), 
    show=True
    )

# %%
barplot(
    df = df_ranking_combined['region'], 
    x='mean_homicides_rate', 
    y='Region_2', 
    height=800,
    orientation='h', 
    color='Region_2',
    facet_col='Periodo',
    cols_wrap=1, 
    barmode='relative',
    vertical_spacing = 0.03,
    color_discrete_map=COLOR_MAP['Region_2'], 
    hover_data=HOVER_DATA['ranking_region'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_region'],
    title=f"Ranking Mundial de Homicidios por País para diferentes Periodos",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_region']), 
    show=True
    )

# %%
barplot(
    df = df_ranking_combined['region'], 
    x='mean_homicides_rate', 
    y='Region_2', 
    height=800,
    orientation='h', 
    color='Region_2',
    facet_col='Periodo',
    cols_wrap=2, 
    barmode='relative',
    vertical_spacing = 0.03,
    color_discrete_map=COLOR_MAP['Region_2'], 
    hover_data=HOVER_DATA['ranking_region'], 
    labels=LABELS['ranking'],
    hovertemplate=HOVER_TEMPLATES['ranking_region'],
    title=f"Ranking Mundial de Homicidios por País para diferentes Periodos",
    plot_save_path=os.path.join(PROJECT_PATH, 'plots', PLOT_FILENAME['ranking_region']), 
    show=True
    )
