# %%
import os
import polars as pl

# %%
SCRIPT_PATH = os.getcwd() # os.path.dirname(os.path.abspath(__file__))
PROJECT_PATH = os.path.join(SCRIPT_PATH, '..')
OUTPUT_DIR = os.path.join(PROJECT_PATH, 'data', 'raw')
OUTPUT_FILE = os.path.join(OUTPUT_DIR, 'eurostat_intentional_homicide_rate.csv')

# %%
df_homicides_eurostat = pl.read_csv(OUTPUT_FILE)
df_homicides_eurostat
# Out:
# shape: (41, 20)
# ┌──────┬──────────┬─────────┬─────────────────┬───┬──────┬──────┬──────┬──────┐
# │ freq ┆ iccs     ┆ unit    ┆ geo\TIME_PERIOD ┆ … ┆ 2020 ┆ 2021 ┆ 2022 ┆ 2023 │
# │ ---  ┆ ---      ┆ ---     ┆ ---             ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---  │
# │ str  ┆ str      ┆ str     ┆ str             ┆   ┆ f64  ┆ f64  ┆ f64  ┆ f64  │
# ╞══════╪══════════╪═════════╪═════════════════╪═══╪══════╪══════╪══════╪══════╡
# │ A    ┆ ICCS0101 ┆ P_HTHAB ┆ AL              ┆ … ┆ 1.83 ┆ 2.16 ┆ 1.5  ┆ 1.23 │
# │ A    ┆ ICCS0101 ┆ P_HTHAB ┆ AT              ┆ … ┆ 0.61 ┆ 0.66 ┆ 0.72 ┆ 0.82 │
# │ A    ┆ ICCS0101 ┆ P_HTHAB ┆ BA              ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ A    ┆ ICCS0101 ┆ P_HTHAB ┆ BE              ┆ … ┆ 1.29 ┆ 1.36 ┆ 1.59 ┆ 1.38 │
# │ A    ┆ ICCS0101 ┆ P_HTHAB ┆ BG              ┆ … ┆ 0.96 ┆ 1.29 ┆ 1.11 ┆ 1.15 │
# │ …    ┆ …        ┆ …       ┆ …               ┆ … ┆ …    ┆ …    ┆ …    ┆ …    │
# ...

# %%
df_homicides_eurostat['geo\TIME_PERIOD'].unique().to_list()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_13660\3963233034.py:1: SyntaxWarning: invalid escape sequence '\T'
#   df_homicides_eurostat['geo\TIME_PERIOD'].unique().to_list()
# ['IE',
#  'MK',
#  'RS',
#  'EE',
#  'CZ',
#  'SI',
#  'XK',
#  'AT',
#  'BG',
#  'UKM',
#  'UKC-L',
#  'FR',
#  'EL',
#  'HR',
#  'PL',
#  'FI',
#  'LI',
#  'CH',
#  'ME',
#  'LT',
#  'AL',
#  'SK',
#  'TR',
#  'LU',
#  'NL',
#  'RO',
#  'MT',
#  'IS',
#  'DE',
#  'CY',
#  'BE',
#  'ES',
#  'LV',
#  'IT',
#  'UKN',
#  'DK',
#  'PT',
#  'NO',
#  'BA',
#  'SE',
#  'HU']
